# %% [markdown]
# <img src="data:image/png;base64,..." alt="" />

# %% [markdown]
# ###ProjectX 2020 UofT AI Competition - File metadata
#
# | Date created | Title | Type | Domain | Version |License / confidentiality
# | --- | --- | --- | --- | --- | --- |
# | 09.1..20 | Load Pickle Fire Line | Data man & Visualization | WRF Simulation post-processing | 1.0 | |

# %% [markdown]
# #Load from Pickle Fire Line - WRF Post Processing

# %%
with open('path_to_pickle_file', 'rb') as fp:
    data = pickle.load(fp)
data = data[0]
